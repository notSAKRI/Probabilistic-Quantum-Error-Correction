# %%
from Main.Experiment_class import Dutta3_T1exp

# %%
obj = Dutta3_T1exp(backend = None, use_cif = False, use_mitigation = False)

# %%
obj.load('31st_August_Torino_run1')

# %%
keys = list(obj.storage.keys())

# %%
qubit_pos = [57, 58, 59, 60, 61, 32, 33, 37, 52, 51, 102, 101, 111, 120, 121]
qubit_srt = [4,5,6]

# %%
obj.show('multi_qec_30_1')
